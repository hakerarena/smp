# %% [markdown]
# # Module 1: Data validation and pre-processing technique

# %%
#import library packages
import pandas as p
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load given dataset
data = p.read_csv("/content/combined_stock_data.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Before drop the given dataset

# %%
data.head()
# Out:
#    Unnamed: 0       Date  Label  \
# 0        1988   7/1/2016      1
# 1        1987  6/30/2016      1
# 2        1986  6/29/2016      1
# 3        1985  6/28/2016      1
# 4        1984  6/27/2016      0
#
#                                                 Top1  \
# 0  A 117-year-old woman in Mexico City finally re...
# 1  Jamaica proposes marijuana dispensers for tour...
# 2                   Explosion At Airport In Istanbul
# 3  2,500 Scientists To Australia: If You Want To ...
# 4  Barclays and RBS shares suspended from trading...
#
#                                                 Top2  \
# 0   IMF chief backs Athens as permanent Olympic host
# 1  Stephen Hawking says pollution and 'stupidity'...
# 2  Yemeni former president: Terrorism is the offs...
# 3  The personal details of 112,000 French police ...
# 4  Pope says Church should ask forgiveness from g...
#
#                                                 Top3  \
# 0  The president of France says if Brexit won, so...
# ...

# %%
#shape
data.shape
# Out:
# (1989, 34)

# %% [markdown]
# After drop the given dataset

# %%
df=data.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0       Date  Label  \
# 0        1988   7/1/2016      1
# 1        1987  6/30/2016      1
# 2        1986  6/29/2016      1
# 3        1985  6/28/2016      1
# 4        1984  6/27/2016      0
#
#                                                 Top1  \
# 0  A 117-year-old woman in Mexico City finally re...
# 1  Jamaica proposes marijuana dispensers for tour...
# 2                   Explosion At Airport In Istanbul
# 3  2,500 Scientists To Australia: If You Want To ...
# 4  Barclays and RBS shares suspended from trading...
#
#                                                 Top2  \
# 0   IMF chief backs Athens as permanent Olympic host
# 1  Stephen Hawking says pollution and 'stupidity'...
# 2  Yemeni former president: Terrorism is the offs...
# 3  The personal details of 112,000 French police ...
# 4  Pope says Church should ask forgiveness from g...
#
#                                                 Top3  \
# 0  The president of France says if Brexit won, so...
# ...

# %%
#shape
df.shape
# Out:
# (1986, 34)

# %%
#show columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
#        'Objectivity', 'Positive', 'Neutral', 'Negative'],
#       dtype='object')

# %%
#To describe the dataframe
df.describe()
# Out:
#         Unnamed: 0        Label  Subjectivity  Objectivity     Positive  \
# count  1986.000000  1986.000000   1986.000000  1986.000000  1986.000000
# mean    994.843907     0.534743     56.712522    43.287478    19.966718
# std     574.301065     0.498917     21.557927    21.557927    16.373424
# min       0.000000     0.000000      0.000000     0.000000     0.000000
# 25%     498.250000     0.000000     40.000000    28.571429     8.333333
# 50%     995.500000     1.000000     54.545455    45.454545    18.181818
# 75%    1491.750000     1.000000     71.428571    60.000000    28.571429
# max    1988.000000     1.000000    100.000000   100.000000   100.000000
#
#            Neutral     Negative
# count  1986.000000  1986.000000
# mean     43.287478    36.745804
# std      21.557927    21.109970
# min       0.000000     0.000000
# 25%      28.571429    21.859903
# 50%      45.454545    33.333333
# 75%      60.000000    50.000000
# max     100.000000   100.000000

# %%
del df['Unnamed: 0']

# %%
#Checking datatype and information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1986 entries, 0 to 1988
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1986 non-null   object
#  1   Label         1986 non-null   int64
#  2   Top1          1986 non-null   object
#  3   Top2          1986 non-null   object
#  4   Top3          1986 non-null   object
#  5   Top4          1986 non-null   object
#  6   Top5          1986 non-null   object
#  7   Top6          1986 non-null   object
#  8   Top7          1986 non-null   object
#  9   Top8          1986 non-null   object
#  10  Top9          1986 non-null   object
#  11  Top10         1986 non-null   object
#  12  Top11         1986 non-null   object
#  13  Top12         1986 non-null   object
#  14  Top13         1986 non-null   object
#  15  Top14         1986 non-null   object
#  16  Top15         1986 non-null   object
#  17  Top16         1986 non-null   object
# ...

# %% [markdown]
# Checking duplicate values of dataframe

# %%
#Checking for duplicate data
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1984    False
# 1985    False
# 1986    False
# 1987    False
# 1988    False
# Length: 1986, dtype: bool

# %%
#find sum of duplicate data
sum(df.duplicated())
# Out:
# 0

# %%
#Checking sum of missing values
df.isnull().sum()
# Out:
# Date            0
# Label           0
# Top1            0
# Top2            0
# Top3            0
# Top4            0
# Top5            0
# Top6            0
# Top7            0
# Top8            0
# Top9            0
# Top10           0
# Top11           0
# Top12           0
# Top13           0
# Top14           0
# Top15           0
# Top16           0
# Top17           0
# Top18           0
# Top19           0
# Top20           0
# Top21           0
# Top22           0
# Top23           0
# Top24           0
# Top25           0
# Para            0
# Subjectivity    0
# Objectivity     0
# Positive        0
# Neutral         0
# Negative        0
# dtype: int64

# %%
df.Label.unique()
# Out:
# array([1, 0])

# %%
df.Subjectivity.unique()
# Out:
# array([ 60.        , 100.        ,  80.        ,  42.85714286,
#         33.33333333,  50.        ,  71.42857143,  66.66666667,
#         75.        ,  55.55555556,  40.        ,  25.        ,
#         87.5       ,  83.33333333,  57.14285714,  88.88888889,
#          0.        ,  28.57142857,  62.5       ,  27.27272727,
#         37.5       ,  20.        ,  85.71428571,  44.44444444,
#         41.66666667,  36.36363636,  16.66666667,  14.28571429,
#         77.77777778,  38.46153846,  54.54545455,  70.        ,
#         30.        ,  63.63636364,  58.33333333,  61.53846154,
#         45.45454545,  72.72727273,  43.75      ,  90.        ,
#         41.17647059,   8.33333333,  46.66666667,  47.36842105,
#         64.28571429,  53.84615385,  47.05882353,  22.22222222,
#         30.76923077,  31.25      ,  35.71428571,  81.81818182,
#         29.41176471,  35.29411765,  23.07692308,  46.15384615,
#         53.33333333,  91.66666667,  26.66666667,  12.5       ,
# ...

# %%
df.Objectivity.unique()
# Out:
# array([ 40.        ,   0.        ,  20.        ,  57.14285714,
#         66.66666667,  50.        ,  28.57142857,  33.33333333,
#         25.        ,  44.44444444,  60.        ,  75.        ,
#         12.5       ,  16.66666667,  42.85714286,  11.11111111,
#        100.        ,  71.42857143,  37.5       ,  72.72727273,
#         62.5       ,  80.        ,  14.28571429,  55.55555556,
#         58.33333333,  63.63636364,  83.33333333,  85.71428571,
#         22.22222222,  61.53846154,  45.45454545,  30.        ,
#         70.        ,  36.36363636,  41.66666667,  38.46153846,
#         54.54545455,  27.27272727,  56.25      ,  10.        ,
#         58.82352941,  91.66666667,  53.33333333,  52.63157895,
#         35.71428571,  46.15384615,  52.94117647,  77.77777778,
#         69.23076923,  68.75      ,  64.28571429,  18.18181818,
#         70.58823529,  64.70588235,  76.92307692,  53.84615385,
#         46.66666667,   8.33333333,  73.33333333,  87.5       ,
# ...

# %%
df.Positive.unique()
# Out:
# array([  0.        , 100.        ,  16.66666667,  33.33333333,
#         28.57142857,  22.22222222,  20.        ,  50.        ,
#         60.        ,  37.5       ,  57.14285714,  25.        ,
#         14.28571429,  40.        ,  44.44444444,  75.        ,
#         12.5       ,  42.85714286,  58.33333333,  66.66666667,
#         11.11111111,  18.18181818,  15.38461538,   9.09090909,
#         10.        ,  45.45454545,  83.33333333,  27.27272727,
#         30.        ,  36.36363636,  62.5       ,  41.66666667,
#         13.33333333,  18.75      ,  30.76923077,  21.42857143,
#         29.41176471,  23.07692308,  26.66666667,   6.66666667,
#         36.84210526,   8.33333333,  55.55555556,   6.25      ,
#          7.14285714,  17.64705882,  31.25      ,   5.88235294,
#          7.69230769,  35.71428571,  11.76470588,   5.55555556,
#         27.77777778,  15.78947368,  23.52941176,  10.52631579,
#         38.46153846,   4.54545455,   5.26315789,  15.        ,
# ...

# %%
df.Neutral.unique()
# Out:
# array([ 40.        ,   0.        ,  20.        ,  57.14285714,
#         66.66666667,  50.        ,  28.57142857,  33.33333333,
#         25.        ,  44.44444444,  60.        ,  75.        ,
#         12.5       ,  16.66666667,  42.85714286,  11.11111111,
#        100.        ,  71.42857143,  37.5       ,  72.72727273,
#         62.5       ,  80.        ,  14.28571429,  55.55555556,
#         58.33333333,  63.63636364,  83.33333333,  85.71428571,
#         22.22222222,  61.53846154,  45.45454545,  30.        ,
#         70.        ,  36.36363636,  41.66666667,  38.46153846,
#         54.54545455,  27.27272727,  56.25      ,  10.        ,
#         58.82352941,  91.66666667,  53.33333333,  52.63157895,
#         35.71428571,  46.15384615,  52.94117647,  77.77777778,
#         69.23076923,  68.75      ,  64.28571429,  18.18181818,
#         70.58823529,  64.70588235,  76.92307692,  53.84615385,
#         46.66666667,   8.33333333,  73.33333333,  87.5       ,
# ...

# %%
df.Negative.unique()
# Out:
# array([ 60.        ,   0.        ,  80.        ,  42.85714286,
#         16.66666667, 100.        ,  66.66666667,  50.        ,
#         75.        ,  33.33333333,  20.        ,  25.        ,
#         37.5       ,  40.        ,  57.14285714,  44.44444444,
#         12.5       ,  14.28571429,  28.57142857,  71.42857143,
#         27.27272727,  83.33333333,  18.18181818,  22.22222222,
#         23.07692308,  45.45454545,  41.66666667,  70.        ,
#         30.        ,  55.55555556,  10.        ,  11.11111111,
#         46.15384615,  26.66666667,   7.69230769,   9.09090909,
#         21.42857143,  11.76470588,  15.38461538,  30.76923077,
#          8.33333333,  62.5       ,   6.66666667,  13.33333333,
#         18.75      ,  10.52631579,  36.36363636,  54.54545455,
#         31.25      ,  38.46153846,  29.41176471,  41.17647059,
#         72.72727273,  85.71428571,  17.64705882,  23.52941176,
#         27.77777778,  31.57894737,  35.29411765,  35.        ,
# ...

# %% [markdown]
# To validate Age of patients:

# %%
print("Minimum value of Subjectivity of News is:", df.Subjectivity.min())
print("Maximum value of Subjectivity of News is:", df.Subjectivity.max())
# Out:
# Minimum value of Subjectivity of News is: 0.0
# Maximum value of Subjectivity of News is: 100.0

# %%
print("News of Subjectivity ranges :", sorted(df['Subjectivity'].unique()))
# Out:
# News of Subjectivity ranges : [0.0, 6.666666667, 8.333333333, 9.090909091, 12.5, 13.33333333, 14.28571429, 15.78947368, 16.66666667, 18.18181818, 18.75, 19.04761905, 20.0, 21.05263158, 21.42857143, 21.73913043, 22.22222222, 22.5, 22.72727273, 23.07692308, 23.52941176, 23.80952381, 24.0, 25.0, 26.31578947, 26.66666667, 26.92307692, 27.27272727, 27.5862069, 27.77777778, 28.0, 28.57142857, 29.03225806, 29.16666667, 29.41176471, 30.0, 30.43478261, 30.76923077, 31.25, 31.57894737, 31.81818182, 32.0, 33.33333333, 34.61538462, 34.7826087, 35.0, 35.29411765, 35.71428571, 36.0, 36.36363636, 36.84210526, 37.03703704, 37.5, 38.0952381, 38.46153846, 38.70967742, 38.88888889, 39.28571429, 40.0, 40.90909091, 41.17647059, 41.66666667, 42.10526316, 42.30769231, 42.85714286, 43.47826087, 43.75, 44.0, 44.44444444, 44.82758621, 45.0, 45.45454545, 45.83333333, 46.15384615, 46.66666667, 47.05882353, 47.36842105, 47.61904762, 47.82608696, 48.0, 50.0, 52.17391304, 52.38095238, 52.63157895, 52.94117647, 53.
# ...

# %%
p.Categorical(df['Subjectivity']).describe()
# Out:
#              counts     freqs
# categories
# 0.0               2  0.001007
# 6.666666667       1  0.000504
# 8.333333333       2  0.001007
# 9.090909091       1  0.000504
# 12.5              2  0.001007
# ...             ...       ...
# 88.88888889       5  0.002518
# 90.0              2  0.001007
# 91.66666667       1  0.000504
# 92.85714286       1  0.000504
# 100.0           185  0.093152
#
# [121 rows x 2 columns]

# %%
p.Categorical(df['Objectivity']).describe()
# Out:
#              counts     freqs
# categories
# 0.0             185  0.093152
# 7.142857143       1  0.000504
# 8.333333333       1  0.000504
# 10.0              2  0.001007
# 11.11111111       5  0.002518
# ...             ...       ...
# 87.5              2  0.001007
# 90.90909091       1  0.000504
# 91.66666667       2  0.001007
# 93.33333333       1  0.000504
# 100.0             2  0.001007
#
# [121 rows x 2 columns]

# %%
df['Label'].value_counts()
# Out:
# 1    1062
# 0     924
# Name: Label, dtype: int64

# %%
df.corr()
# Out:
#                  Label  Subjectivity  Objectivity  Positive   Neutral  \
# Label         1.000000     -0.009935     0.009935  0.003905  0.009935
# Subjectivity -0.009935      1.000000    -1.000000  0.406829 -1.000000
# Objectivity   0.009935     -1.000000     1.000000 -0.406829  1.000000
# Positive      0.003905      0.406829    -0.406829  1.000000 -0.406829
# Neutral       0.009935     -1.000000     1.000000 -0.406829  1.000000
# Negative     -0.013174      0.705674    -0.705674 -0.360164 -0.705674
#
#               Negative
# Label        -0.013174
# Subjectivity  0.705674
# Objectivity  -0.705674
# Positive     -0.360164
# Neutral      -0.705674
# Negative      1.000000

# %% [markdown]
# Before Pre-Processing:

# %%
df.head()
# Out:
#         Date  Label                                               Top1  \
# 0   7/1/2016      1  A 117-year-old woman in Mexico City finally re...
# 1  6/30/2016      1  Jamaica proposes marijuana dispensers for tour...
# 2  6/29/2016      1                   Explosion At Airport In Istanbul
# 3  6/28/2016      1  2,500 Scientists To Australia: If You Want To ...
# 4  6/27/2016      0  Barclays and RBS shares suspended from trading...
#
#                                                 Top2  \
# 0   IMF chief backs Athens as permanent Olympic host
# 1  Stephen Hawking says pollution and 'stupidity'...
# 2  Yemeni former president: Terrorism is the offs...
# 3  The personal details of 112,000 French police ...
# 4  Pope says Church should ask forgiveness from g...
#
#                                                 Top3  \
# 0  The president of France says if Brexit won, so...
# 1  Boris Johnson says he will not run for Tory pa...
# ...

# %% [markdown]
# After Pre-Processing:

# %%
df.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25', 'Para', 'Subjectivity', 'Objectivity', 'Positive',
#        'Neutral', 'Negative'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
       'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
       'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
       'Top24', 'Top25', 'Para', 'Subjectivity', 'Objectivity', 'Positive',
       'Neutral', 'Negative']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(str)

# %%
df.head()
# Out:
#    Date Label Top1  Top2  Top3  Top4  Top5  Top6  Top7  Top8  ... Top22 Top23  \
# 0  1508     1   84   624  1277   327    50   242   230   460  ...  1232  1447
# 1  1468     1  755  1203   270  1195  1227   994  1061  1031  ...  1438  1466
# 2  1455     1  501  1503  1358   431   264    83   865  1401  ...   591   447
# 3  1449     1   60  1303  1115   634   274   244   636   258  ...    17   245
# 4  1444     0  256  1023  1010  1344  1160  1210   940  1199  ...   388   403
#
#   Top24 Top25 Para Subjectivity Objectivity Positive Neutral Negative
# 0    71   984   84           95          25        0      25       99
# 1  1393   787  755          120           0       96       0        0
# 2   205  1336  501          111           9        0       9      106
# 3    59   850   60           64          56        0      56       84
# 4   901  1000  256           42          78       36      78       34
#
# [5 rows x 33 columns]

# %%
p.crosstab(df.Label,df.Subjectivity)
# Out:
# Subjectivity  0  1  10  100  101  102  103  104  105  106  ...  90  91  92  \
# Label                                                      ...
# 0             1  1   1    0   71    1    1   10   20    5  ...   3   0  23
# 1             1  0   0    1   84    0    0    7   39    3  ...   1   1  35
#
# Subjectivity  93  94  95  96  97  98  99
# Label
# 0             12   1  46   1   6  22   5
# 1             10   1  50   1   4  29   8
#
# [2 rows x 121 columns]

# %%
#Histogram Plot of Age distribution
df['Label'].hist(figsize=(7,6), color='green', alpha=0.7)
plt.xlabel('Label')
plt.ylabel('News')
plt.title('Lebel of distribution of News')
# Out:
# Text(0.5, 1.0, 'Lebel of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Subjectivity'].hist(figsize=(7,6), color='orange', alpha=0.7)
plt.xlabel('Subjectivity')
plt.ylabel('News')
plt.title('Subjectivity of distribution of News')
# Out:
# Text(0.5, 1.0, 'Subjectivity of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Objectivity'].hist(figsize=(7,6), color='indigo', alpha=0.7)
plt.xlabel('Objectivity')
plt.ylabel('News')
plt.title('Objectivity of distribution of News')
# Out:
# Text(0.5, 1.0, 'Objectivity of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Positive'].hist(figsize=(7,6), color='red', alpha=0.7)
plt.xlabel('Positive')
plt.ylabel('News')
plt.title('Positive of distribution of News')
# Out:
# Text(0.5, 1.0, 'Positive of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Neutral'].hist(figsize=(7,6), color='brown', alpha=0.7)
plt.xlabel('Neutral')
plt.ylabel('News')
plt.title('Neutral of distribution of News')
# Out:
# Text(0.5, 1.0, 'Neutral of distribution of News')

# %%
#Histogram Plot of Age distribution
df['Negative'].hist(figsize=(7,6), color='yellow', alpha=0.7)
plt.xlabel('Negative')
plt.ylabel('News')
plt.title('Negative of distribution of News')
# Out:
# Text(0.5, 1.0, 'Negative of distribution of News')

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df, 'Label')
# Out:
# 1    53.47
# 0    46.53
# Name: Label, dtype: float64

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(df, 'Objectivity')
# Out:
# 40     11.13
# 0       9.32
# 19      7.80
# 25      4.83
# 78      4.23
#        ...
# 113     0.05
# 72      0.05
# 1       0.05
# 29      0.05
# 117     0.05
# Name: Objectivity, Length: 121, dtype: float64

# %%
PropByVar(df, 'Subjectivity')
# Out:
# 80     11.13
# 120     9.32
# 101     7.80
# 95      4.83
# 42      4.23
#        ...
# 7       0.05
# 48      0.05
# 119     0.05
# 91      0.05
# 3       0.05
# Name: Subjectivity, Length: 121, dtype: float64

# %%
plt.plot(df["Label"], df["Objectivity"], color='g')
plt.xlabel('Patient Age Details')
plt.ylabel('Gender Details')
plt.title('Patient Age Details by gender')
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5', 'Top6', 'Top7',
#        'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13', 'Top14', 'Top15',
#        'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21', 'Top22', 'Top23',
#        'Top24', 'Top25', 'Para', 'Subjectivity', 'Objectivity', 'Positive',
#        'Neutral', 'Negative'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
       'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
       'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
       'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
       'Objectivity', 'Positive', 'Neutral', 'Negative']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(str)

# %%
df.head()
# Out:
#   Date Label  Top1  Top2  Top3  Top4  Top5  Top6  Top7  Top8  ... Top22 Top23  \
# 0  567     1  1809  1570   310  1240  1432  1146  1133  1388  ...   261   499
# 1  522     1  1715   229  1176   219   255  1980    71    38  ...   489   520
# 2  508     1  1434   562   400  1356  1170  1798  1837   449  ...  1533  1373
# 3  501     1  1543   340   131  1581  1181  1148  1583  1163  ...   779  1149
# 4  496     0  1161    29    15   385   181   237  1921   223  ...  1307  1325
#
#   Top24 Top25  Para Subjectivity Objectivity Positive Neutral Negative
# 0  1665  1969  1809          116          39        0      39      109
# 1   439  1750  1715           25           0       96       0        0
# 2  1105   376  1434           15         110        0     110        9
# 3  1531  1821  1543           82          73        0      73       93
# 4  1878     4  1161           58          97       30      97       38
#
# [5 rows x 33 columns]

# %%
#preprocessing, split test and dataset, split response variable
X = df.drop(labels='Label', axis=1)
#Response variable
y = df.loc[:,'Label']

# %%
#We'll use a test size of 30%. We also stratify the split on the response variable, which is very important to do because there are so few fraudulent transactions.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)
print("Number of training dataset: ", len(X_train))
print("Number of test dataset: ", len(X_test))
print("Total number of dataset: ", len(X_train)+len(X_test))
# Out:
# Number of training dataset:  1390
# Number of test dataset:  596
# Total number of dataset:  1986

# %%
def qul_No_qul_bar_plot(df, bygroup):
    dataframe_by_Group = p.crosstab(df[bygroup], columns=df["Label"], normalize = 'index')
    dataframe_by_Group = n.round((dataframe_by_Group * 100), decimals=2)
    ax = dataframe_by_Group.plot.bar(figsize=(15,7));
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:3.0f}%'.format(x) for x in vals]);
    ax.set_xticklabels(dataframe_by_Group.index,rotation = 0, fontsize = 15);
    ax.set_title('Stock stable or not by given attributes (%) (by ' + dataframe_by_Group.index.name + ')\n', fontsize = 15)
    ax.set_xlabel(dataframe_by_Group.index.name, fontsize = 12)
    ax.set_ylabel('(%)', fontsize = 12)
    ax.legend(loc = 'upper left',bbox_to_anchor=(1.0,1.0), fontsize= 12)
    rects = ax.patches

    # Add Data Labels

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, 
                height + 2, 
                str(height)+'%', 
                ha='center', 
                va='bottom',
                fontsize = 12)
    return dataframe_by_Group

# %%
qul_No_qul_bar_plot(df, 'Subjectivity')
# Out:
# Label              0       1
# Subjectivity
# 0              50.00   50.00
# 1             100.00    0.00
# 10              0.00  100.00
# 100            46.61   53.39
# 101            50.00   50.00
# ...              ...     ...
# 95             50.00   50.00
# 96              0.00  100.00
# 97              0.00  100.00
# 98             50.00   50.00
# 99             20.00   80.00
#
# [121 rows x 2 columns]

# %%
data1 = p.read_csv("/content/upload_DJIA_table.csv")

# %%
data1
# Out:
#            Date         Open         High          Low        Close  \
# 0      7/1/2016  17924.24023  18002.38086  17916.91016  17949.36914
# 1     6/30/2016  17712.75977  17930.60938  17711.80078  17929.99023
# 2     6/29/2016  17456.01953  17704.50977  17456.01953  17694.67969
# 3     6/28/2016  17190.50977  17409.72070  17190.50977  17409.72070
# 4     6/27/2016  17355.21094  17355.21094  17063.08008  17140.24023
# ...         ...          ...          ...          ...          ...
# 1984  8/14/2008  11532.07031  11718.28027  11450.88965  11615.92969
# 1985  8/13/2008  11632.80957  11633.78027  11453.33984  11532.95996
# 1986  8/12/2008  11781.70020  11782.34961  11601.51953  11642.46973
# 1987  8/11/2008  11729.66992  11867.11035  11675.53027  11782.34961
# 1988   8/8/2008  11432.08984  11759.95996  11388.04004  11734.32031
#
#          Volume    Adj Close
# 0      82160000  17949.36914
# 1     133030000  17929.99023
# 2     106380000  17694.67969
# 3     112190000  17409.72070
# ...

# %%
df=p.concat([data1,data],axis=1)

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0      7/1/2016  17924.24023  18002.38086  17916.91016  17949.36914
# 1     6/30/2016  17712.75977  17930.60938  17711.80078  17929.99023
# 2     6/29/2016  17456.01953  17704.50977  17456.01953  17694.67969
# 3     6/28/2016  17190.50977  17409.72070  17190.50977  17409.72070
# 4     6/27/2016  17355.21094  17355.21094  17063.08008  17140.24023
# ...         ...          ...          ...          ...          ...
# 1984  8/14/2008  11532.07031  11718.28027  11450.88965  11615.92969
# 1985  8/13/2008  11632.80957  11633.78027  11453.33984  11532.95996
# 1986  8/12/2008  11781.70020  11782.34961  11601.51953  11642.46973
# 1987  8/11/2008  11729.66992  11867.11035  11675.53027  11782.34961
# 1988   8/8/2008  11432.08984  11759.95996  11388.04004  11734.32031
#
#          Volume    Adj Close  Unnamed: 0       Date  Label  ...  \
# 0      82160000  17949.36914        1988   7/1/2016      1  ...
# ...

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1989.000000   1989.000000   1989.000000   1989.000000  1.989000e+03
# mean   13459.116049  13541.303173  13372.931728  13463.032255  1.628110e+08
# std     3143.281634   3136.271725   3150.420934   3144.006996  9.392343e+07
# min     6547.009766   6709.609863   6469.950195   6547.049805  8.410000e+06
# 25%    10907.339840  11000.980470  10824.759770  10913.379880  1.000000e+08
# 50%    13022.049810  13088.110350  12953.129880  13025.580080  1.351700e+08
# 75%    16477.699220  16550.070310  16392.769530  16478.410160  1.926000e+08
# max    18315.060550  18351.359380  18272.560550  18312.390630  6.749200e+08
#
#           Adj Close   Unnamed: 0        Label  Subjectivity  Objectivity  \
# count   1989.000000  1989.000000  1989.000000   1986.000000  1986.000000
# mean   13463.032255   994.000000     0.535445     56.712522    43.287478
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close',
#        'Unnamed: 0', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
#        'Objectivity', 'Positive', 'Neutral', 'Negative'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close','Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
       'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
       'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
       'Top22', 'Top23', 'Top24', 'Top25', 'Subjectivity',
       'Objectivity', 'Positive', 'Neutral', 'Negative']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(str)

# %%
df
# Out:
#            Date  Open  High   Low Close Volume Adj Close  Unnamed: 0  \
# 0      7/1/2016  1881  1884  1907  1886    209      1886        1988
# 1     6/30/2016  1779  1853  1823  1882    902      1882        1987
# 2     6/29/2016  1689  1735  1711  1767    560      1767        1986
# 3     6/28/2016  1650  1663  1663  1676    634      1676        1985
# 4     6/27/2016  1669  1654  1638  1636    965      1636        1984
# ...         ...   ...   ...   ...   ...    ...       ...         ...
# 1984  8/14/2008   636   658   639   653   1162       653           4
# 1985  8/13/2008   657   644   641   635   1331       635           3
# 1986  8/12/2008   677   665   665   656   1273       656           2
# 1987  8/11/2008   670   676   674   675   1335       675           1
# 1988   8/8/2008   613   663   624   669   1494       669           0
#
#            Date Label  ... Top22 Top23 Top24 Top25  \
# 0      7/1/2016     1  ...  1232  1447    71   984
# ...

# %%
#According to the cross-validated MCC scores, the random forest is the best-performing model, so now let's evaluate its performance on the test set.
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef, cohen_kappa_score, accuracy_score, average_precision_score, roc_auc_score

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close',
#        'Unnamed: 0', 'Date', 'Label', 'Top1', 'Top2', 'Top3', 'Top4', 'Top5',
#        'Top6', 'Top7', 'Top8', 'Top9', 'Top10', 'Top11', 'Top12', 'Top13',
#        'Top14', 'Top15', 'Top16', 'Top17', 'Top18', 'Top19', 'Top20', 'Top21',
#        'Top22', 'Top23', 'Top24', 'Top25', 'Para', 'Subjectivity',
#        'Objectivity', 'Positive', 'Neutral', 'Negative'],
#       dtype='object')

# %%
X=df[['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close','Subjectivity','Objectivity', 'Positive', 'Neutral', 'Negative']]

# %%
X
# Out:
#       Open  High   Low Close Volume Adj Close Subjectivity Objectivity  \
# 0     1881  1884  1907  1886    209      1886           95          25
# 1     1779  1853  1823  1882    902      1882          120           0
# 2     1689  1735  1711  1767    560      1767          111           9
# 3     1650  1663  1663  1676    634      1676           64          56
# 4     1669  1654  1638  1636    965      1636           42          78
# ...    ...   ...   ...   ...    ...       ...          ...         ...
# 1984   636   658   639   653   1162       653           71          49
# 1985   657   644   641   635   1331       635           54          66
# 1986   677   665   665   656   1273       656           90          30
# 1987   670   676   674   675   1335       675          113           7
# 1988   613   663   624   669   1494       669          108          12
#
#      Positive Neutral Negative
# 0           0      25       99
# 1          96       0        0
# ...

# %%
#Response variable
y = df.loc[:,'Label']

# %%
#We'll use a test size of 30%. We also stratify the split on the response variable, which is very important to do because there are so few fraudulent transactions.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
# Prevent view warnings
X_train.is_copy = False
X_test.is_copy = False

# %%
from sklearn.linear_model import LogisticRegression
logR= LogisticRegression()

logR.fit(X_train,y_train)

predictR = logR.predict(X_test)

print("")
print('Classification report of Logistic Regression Results:')
print("")

print(classification_report(y_test,predictR))
x = (accuracy_score(y_test,predictR)*100)

print('Accuracy result of Logistic Regression is:', x)
print("")
cm1=confusion_matrix(y_test,predictR)
print('Confusion Matrix result of Logistic Regression is:\n',cm1)
print("")
sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
print("")
# Out:
# Classification report of Logistic Regression Results:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       277
#            1       0.97      0.97      0.97       319
#
#     accuracy                           0.97       596
#    macro avg       0.97      0.97      0.97       596
# weighted avg       0.97      0.97      0.97       596
#
# Accuracy result of Logistic Regression is: 96.97986577181209
#
# Confusion Matrix result of Logistic Regression is:
#  [[269   8]
#  [ 10 309]]
#
# Sensitivity :  0.9711191335740073
#
# Specificity :  0.9686520376175548

# %%
TN = cm1[0][0]
FN = cm1[1][0]
TP = cm1[1][1]
FP = cm1[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 309
# True Negative : 269
# False Positive : 8
# False Negative : 10
#
# True Positive Rate : 0.9686520376175548
# True Negative Rate : 0.9711191335740073
# False Positive Rate : 0.02888086642599278
# False Negative Rate : 0.03134796238244514
#
# Positive Predictive Value : 0.9747634069400631
# Negative predictive value : 0.96415770609319

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

dtree.fit(X_train, y_train)

predictDT = dtree.predict(X_test)

print("")
print('Classification report of Decision Tree Classifier Results:')
print("")

print(classification_report(y_test,predictDT))
x = (accuracy_score(y_test,predictDT)*100)

print('Accuracy result of Decision Tree Classifier is', x)
print("")
cm2=confusion_matrix(y_test,predictDT)
print('Confusion Matrix result of Decision Tree Classifier is:\n', confusion_matrix(y_test,predictDT))
print("")

sensitivity1 = cm2[0,0]/(cm2[0,0]+cm2[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm2[1,1]/(cm2[1,0]+cm2[1,1])
print('Specificity : ', specificity1)
# Out:
# Classification report of Decision Tree Classifier Results:
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.61      0.62       277
#            1       0.67      0.67      0.67       319
#
#     accuracy                           0.65       596
#    macro avg       0.64      0.64      0.64       596
# weighted avg       0.65      0.65      0.65       596
#
# Accuracy result of Decision Tree Classifier is 64.59731543624162
#
# Confusion Matrix result of Decision Tree Classifier is:
#  [[170 107]
#  [104 215]]
#
# Sensitivity :  0.6137184115523465
#
# Specificity :  0.6739811912225705

# %%
TN = cm2[0][0]
FN = cm2[1][0]
TP = cm2[1][1]
FP = cm2[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 215
# True Negative : 170
# False Positive : 107
# False Negative : 104
#
# True Positive Rate : 0.6739811912225705
# True Negative Rate : 0.6137184115523465
# False Positive Rate : 0.3862815884476534
# False Negative Rate : 0.32601880877742945
#
# Positive Predictive Value : 0.6677018633540373
# Negative predictive value : 0.6204379562043796

# %%
#According to the cross-validated MCC scores, the random forest is the best-performing model, so now let's evaluate its performance on the test set.
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef, cohen_kappa_score, accuracy_score, average_precision_score, roc_auc_score

# %%
X=df[['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close','Subjectivity','Objectivity', 'Positive', 'Neutral', 'Negative']]
#Response variable
y = df.loc[:,'Label']

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

rfc.fit(X_train,y_train)

predictR = rfc.predict(X_test)

print("")
print('Classification report of Random Forest Results:')
print("")

print(classification_report(y_test,predictR))
x = (accuracy_score(y_test,predictR)*100)

print('Accuracy result of Random Forest is:', x)
print("")
cm1=confusion_matrix(y_test,predictR)
print('Confusion Matrix result of Random Forest is:\n',cm1)
print("")
sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
print("")
# Out:
# Classification report of Random Forest Results:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64       277
#            1       0.69      0.73      0.71       319
#
#     accuracy                           0.68       596
#    macro avg       0.68      0.68      0.68       596
# weighted avg       0.68      0.68      0.68       596
#
# Accuracy result of Random Forest is: 67.9530201342282
#
# Confusion Matrix result of Random Forest is:
#  [[172 105]
#  [ 86 233]]
#
# Sensitivity :  0.6209386281588448
#
# Specificity :  0.7304075235109718

# %%
TN = cm1[0][0]
FN = cm1[1][0]
TP = cm1[1][1]
FP = cm1[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 233
# True Negative : 172
# False Positive : 105
# False Negative : 86
#
# True Positive Rate : 0.7304075235109718
# True Negative Rate : 0.6209386281588448
# False Positive Rate : 0.37906137184115524
# False Negative Rate : 0.26959247648902823
#
# Positive Predictive Value : 0.6893491124260355
# Negative predictive value : 0.6666666666666666

# %%
from sklearn.svm import SVC
s = SVC()

s.fit(X_train,y_train)

predicts = s.predict(X_test)

print("")
print('Classification report of Support Vector Machines Results:')
print("")

print(classification_report(y_test,predicts))
x = (accuracy_score(y_test,predicts)*100)

print('Accuracy result of Support Vector Machines is:', x)
print("")
cm2=confusion_matrix(y_test,predicts)
print('Confusion Matrix result of Support Vector Machines is:\n',cm2)
print("")
sensitivity1 = cm2[0,0]/(cm2[0,0]+cm2[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm2[1,1]/(cm2[1,0]+cm2[1,1])
print('Specificity : ', specificity1)
print("")
# Out:
# Classification report of Support Vector Machines Results:
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.18      0.28       277
#            1       0.56      0.90      0.69       319
#
#     accuracy                           0.57       596
#    macro avg       0.59      0.54      0.48       596
# weighted avg       0.59      0.57      0.50       596
#
# Accuracy result of Support Vector Machines is: 56.711409395973156
#
# Confusion Matrix result of Support Vector Machines is:
#  [[ 50 227]
#  [ 31 288]]
#
# Sensitivity :  0.18050541516245489
#
# Specificity :  0.9028213166144201

# %%
TN = cm2[0][0]
FN = cm2[1][0]
TP = cm2[1][1]
FP = cm2[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 288
# True Negative : 50
# False Positive : 227
# False Negative : 31
#
# True Positive Rate : 0.9028213166144201
# True Negative Rate : 0.18050541516245489
# False Positive Rate : 0.8194945848375451
# False Negative Rate : 0.09717868338557993
#
# Positive Predictive Value : 0.5592233009708738
# Negative predictive value : 0.6172839506172839

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

gnb.fit(X_train,y_train)

predictR = gnb.predict(X_test)

print("")
print('Classification report of Naive Bayes Results:')
print("")

print(classification_report(y_test,predictR))
x = (accuracy_score(y_test,predictR)*100)

print('Accuracy result of Naive Bayes is:', x)
print("")
cm1=confusion_matrix(y_test,predictR)
print('Confusion Matrix result of Naive Bayes is:\n',cm1)
print("")
sensitivity1 = cm1[0,0]/(cm1[0,0]+cm1[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm1[1,1]/(cm1[1,0]+cm1[1,1])
print('Specificity : ', specificity1)
print("")
# Out:
# Classification report of Naive Bayes Results:
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.31      0.36       277
#            1       0.52      0.66      0.58       319
#
#     accuracy                           0.49       596
#    macro avg       0.48      0.48      0.47       596
# weighted avg       0.48      0.49      0.48       596
#
# Accuracy result of Naive Bayes is: 49.49664429530201
#
# Confusion Matrix result of Naive Bayes is:
#  [[ 86 191]
#  [110 209]]
#
# Sensitivity :  0.3104693140794224
#
# Specificity :  0.6551724137931034

# %%
TN = cm1[0][0]
FN = cm1[1][0]
TP = cm1[1][1]
FP = cm1[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 209
# True Negative : 86
# False Positive : 191
# False Negative : 110
#
# True Positive Rate : 0.6551724137931034
# True Negative Rate : 0.3104693140794224
# False Positive Rate : 0.6895306859205776
# False Negative Rate : 0.3448275862068966
#
# Positive Predictive Value : 0.5225
# Negative predictive value : 0.4387755102040816

# %%
from sklearn.neighbors import KNeighborsClassifier
knnc = KNeighborsClassifier()

knnc.fit(X_train,y_train)

predictR = knnc.predict(X_test)

print("")
print('Classification report of K-Nearest Neighbor Results:')
print("")

print(classification_report(y_test,predictR))
x = (accuracy_score(y_test,predictR)*100)

print('Accuracy result of K-Nearest Neighbor is:', x)
print("")
cm2=confusion_matrix(y_test,predictR)
print('Confusion Matrix result of K-Nearest Neighbor is:\n',cm2)
print("")
sensitivity1 = cm2[0,0]/(cm2[0,0]+cm2[0,1])
print('Sensitivity : ', sensitivity1 )
print("")
specificity1 = cm2[1,1]/(cm2[1,0]+cm2[1,1])
print('Specificity : ', specificity1)
print("")
# Out:
# Classification report of K-Nearest Neighbor Results:
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.56       277
#            1       0.62      0.65      0.64       319
#
#     accuracy                           0.60       596
#    macro avg       0.60      0.60      0.60       596
# weighted avg       0.60      0.60      0.60       596
#
# Accuracy result of K-Nearest Neighbor is: 60.06711409395973
#
# Confusion Matrix result of K-Nearest Neighbor is:
#  [[150 127]
#  [111 208]]
#
# Sensitivity :  0.5415162454873647
#
# Specificity :  0.6520376175548589

# %%
TN = cm2[0][0]
FN = cm2[1][0]
TP = cm2[1][1]
FP = cm2[0][1]
print("True Positive :",TP)
print("True Negative :",TN)
print("False Positive :",FP)
print("False Negative :",FN)
print("")
TPR = TP/(TP+FN)
TNR = TN/(TN+FP)
FPR = FP/(FP+TN)
FNR = FN/(TP+FN)
print("True Positive Rate :",TPR)
print("True Negative Rate :",TNR)
print("False Positive Rate :",FPR)
print("False Negative Rate :",FNR)
print("")
PPV = TP/(TP+FP)
NPV = TN/(TN+FN)
print("Positive Predictive Value :",PPV)
print("Negative predictive value :",NPV)
# Out:
# True Positive : 208
# True Negative : 150
# False Positive : 127
# False Negative : 111
#
# True Positive Rate : 0.6520376175548589
# True Negative Rate : 0.5415162454873647
# False Positive Rate : 0.4584837545126354
# False Negative Rate : 0.34796238244514105
#
# Positive Predictive Value : 0.6208955223880597
# Negative predictive value : 0.5747126436781609
